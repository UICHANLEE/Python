# %%
import search_matched_sum as se
import random

# %% [markdown]
# ## TimeComplexity가 $NlogN$인경우

# %%
import timeit
code="""
def test_func(arr : list) -> list:
    arr.sort()
    return arr
"""

#call the timeit() method 4 times
print(timeit.timeit(stmt=code))

arr = []
for _ in range(100):
    arr.append(random.randint(1, 100))
    
def test_func(arr : list) -> list:
    arr.sort()
    return arr

# %timeit test_func(arr)
# Out:
# 0.12775420000025406
# 688 ns ± 34.8 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## TimeComplexity가 $N^2$인 경우

# %%
import timeit
code="""
def test_func2():
    return [r for i in range(100)]
"""

#call the timeit() method 4 times
print(timeit.timeit(stmt=code))
    
def test_func2():
    result = 0
    for i in range(len(arr)):
        for j in range(len(arr)):
            return arr[i]*arr[j]
            
# %timeit test_func2()
# Out:
# 0.04200279999986378
# 621 ns ± 16.9 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# [toc]
# # CASE 1
#
# ### TimeComplexity가 $N^2$ 인경우
#
# ```python
# def BubbleSort(arr : list) -> list:
#     n = len(arr)
#     for i in range(n):
#         for j in range(n-i-1):
#             if arr[j] > arr[j+1]:
#                 arr[j], arr[j+1] = arr[j+1], arr[j]
#     return arr
# ```
#
# TimeComplexity가 $n^2$ 를 가지는 BubbleSort를 정의하였다.
#
# ```python
# def search_matched_sum(arr : list, target : int) -> list:
#
#     arr = bubbleSort(arr)# 위에서 정의한 BubbleSort를 이용하여 정렬
#
#     min_index = () # min_index의 값을 넣어줌
#     max_index = () # max_index의 값을 넣어줌
#     target_index = () # 조건을 만족하는 값들의 index 값을 저장할 튜플
#     Total_index = []
#     for i in range(len(arr)):
#         for j in range(len(arr)):
#             if arr.index(arr[i]) < arr.index(arr[j]):# 정렬해준 리스트에서 index값이 작을 경우만 탐색
#                 if arr[i] + arr[j] == target:  # arr리스트에 있는 값들 중 두 값을 더한 것이 target과 같을 경우
#                     min_index = (arr.index(arr[i]))
#                     max_index = (arr.index(arr[j]))
#                     target_index = (min_index, max_index)
#                     if target_index not in Total_index: # 중복된 값이 있는경우 제외
#                         Total_index.append(target_index)
#                     else:
#                         continue
#
#     return Total_index
# ```
#
#
# 입력받은 arr을 $n^2$의 *TimeComplexity* 를 가지는 *BubbleSort*를 이용하여 정렬하여 주었다.
# 그 후 이중 <span style='color: Blue'>for문</span>을 이용하여 ***target*** 의 값을 가지는 값들의 인덱스를 <span style='color: lightskyblue'>min_index, max_index</span>으로 넣어주고 <span style='color: grey'>target_index</span>라는 값으로 추가해주었다.
# 그 튜플을 값으로 가지는 <span style="color: coral">Total_index</span>에 append 해주었다.
# 이렇게 하면 arr안에 있는 두 값의 합이 ***target*** 값으로 가지는 것이 여러 개 일지라도
# 그 값들을 모두 구할 수 있게 된다.
#
# ---

# %%
import timeit
code="""
def bubbleSort(arr : list) -> list:
    n = len(arr)
    for i in range(n):
        for j in range(n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr
"""

#call the timeit() method 4 times
print(timeit.timeit(stmt=code))
arr = []
for _ in range(100):
    arr.append(random.randint(1, 100))
    
def bubbleSort(arr : list) -> list:
    n = len(arr)
    for i in range(n):
        for j in range(n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

# %timeit bubbleSort(arr)
# Out:
# 0.14382260000002134
# 340 µs ± 11.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
import timeit
code="""
def search_matched_sum(arr : list, target : int) -> list:
    arr = bubbleSort(arr)
    
    min_index = ()
    max_index = ()
    index_value = ()
    Total_index = []
    for i in range(len(arr)):
        for j in range(len(arr)):
            if arr.index(arr[i]) < arr.index(arr[j]):
                if arr[i] + arr[j] == target:
                    min_index = (arr.index(arr[i]))
                    max_index = (arr.index(arr[j]))
                    index_value = (min_index, max_index)
                    if index_value not in Total_index:
                        Total_index.append(index_value)
                    else:
                        continue
   
    return Total_index
"""

#call the timeit() method 4 times
print(timeit.timeit(stmt=code))
arr = []
for _ in range(100):
    arr.append(random.randint(1, 100))
    
def search_matched_sum(arr : list, target : int) -> list:
    arr = bubbleSort(arr)
    
    min_index = ()
    max_index = ()
    index_value = ()
    Total_index = []
    for i in range(len(arr)):
        for j in range(len(arr)):
            if arr.index(arr[i]) < arr.index(arr[j]):
                if arr[i] + arr[j] == target:
                    min_index = (arr.index(arr[i]))
                    max_index = (arr.index(arr[j]))
                    index_value = (min_index, max_index)
                    if index_value not in Total_index:
                        Total_index.append(index_value)
                    else:
                        continue
   
    return Total_index

# %timeit search_matched_sum(arr, 6)
# Out:
# 0.15807749999999032
# 16.1 ms ± 559 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # CASE 2
# ### TimeComplexity가 $nlogn$ 일 경우
#
# ```python
# def mergeSort(arr : list) -> list:
#     if len(arr) > 1: #arr의 길이가 1개 초과일 경우 계속
#         mid = len(arr) // 2 #arr의 중간값 인덱스를 찾기 위해 지정
#         left = arr[:mid] # arr에서 중간값까지 left로 지정
#         right = arr[mid:] # arr에서 중간값부터 마지막까지 right로 지정
#
#         mergeSort(left) # left값들을 1개 단위로 계속 쪼개어줌
#         mergeSort(right) # right값들을 1개 단위로 계속 쪼개어줌
#
#         i = 0
#         j = 0
#         k = 0
#
#         while i < len(left) and j < len(right):
#             if left[i] < right[j]:
#                 arr[k] = left[i] #arr의 값에 left[i]와 right[j]의 값을 비교하여 넣어줌
#                 i += 1
#             else:
#                 arr[k] = right[j] #arr의 값에 left[i]와 right[j]의 값을 비교하여 넣어줌
#                 j += 1
#
#             k += 1
#         while i < len(left): # left부터 차례대로 arr에 정렬된 값으로 넣어줌
#             arr[k] = left[i]
#             i += 1
#             k += 1
#         while j < len(right):
#             arr[k] = right[j]
#             j += 1
#             k += 1
#
#     return arr
# ```
#
# TimeComplexity가 항상 $nlogn$를 가지는 mergeSort를 정의하였다.
#
# ```python
# def search_matched_sum(arr : list, target : int) -> list:
#     arr = mergeSort(arr) #arr을 mergeSort로 정렬
#     min_index = ()
#     max_index = ()
#     target_index = ()
#     Total_index = []
#     i = 0
#     while i < len(arr):
#         temp = target - arr[i] # target에서 arr[i]의 값을 빼주어 temp로 지정하여줌
#         if temp in arr[arr.index(arr[i]):]:
#             min_index = arr.index(arr[i])
#             max_index = arr.index(temp)
#             target_index = (min_index, max_index)
#             if target_index not in Total_index:
#                 Total_index.append(target_index)
#             i += 1
#
#         else:
#             i += 1
#     return Total_index
# ```
#
# 입력받은 arr을 $nlogn$의 *TimeComplexity*를 가지는 mergeSort*로 정렬하여주었다.
# 그 후 i* 가 *len(arr)* 보다 작을 동안 <span style='color: pink'>temp</span>라는 값을 ***target*** 에서 arr[i]의 값을 뺀 것으로 지정하여 주었다.
# 만약 <span style='color: pink'>temp</span>값이 arr에 있다면, arr[i]를 <span style='color: lightskyblue'>min_index</span>, <span style='color: pink'>temp</span>를 <span style='color: purple'>max_index</span>로 넣어주었다.
#
# 그 뒤로는 CASE1 과 같이 <span style='color: grey'>target_index</span>라는 값으로 추가해주었고,
# 그 튜플을 값으로 가지는 <span style="color: coral">Total_index</span>에 *append* 해주었다.

# %%
import timeit
code="""
def mergeSort(arr : list) -> list:
    if len(arr) > 1:
        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:]

        mergeSort(left)
        mergeSort(right)
        i = 0
        j = 0
        k = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1

            k += 1
        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1
        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1

    return arr
"""

#call the timeit() method 4 times
print(timeit.timeit(stmt=code))

arr = []
for _ in range(100):
    arr.append(random.randint(1, 100))
    
def mergeSort(arr : list) -> list:
    if len(arr) > 1:
        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:]

        mergeSort(left)
        mergeSort(right)
        i = 0
        j = 0
        k = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1

            k += 1
        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1
        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1

    return arr

# %timeit mergeSort(arr)
# Out:
# 0.17153000000007523
# 197 µs ± 6.12 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
import timeit
code="""
def search_matched_sum(arr : list, target : int) -> list:
    arr = mergeSort(arr)
    min_index = ()
    max_index = ()
    value_index = ()
    Total_index = []
    i = 0
    while i < len(arr):
        temp = target - arr[i]
        if temp in arr[arr.index(arr[i]):]:
            min_index = arr[i]
            max_index = temp
            value_index = (min_index, max_index)
            if value_index not in Total_index:
                Total_index.append(value_index)
            i += 1
        
        else:
            i += 1
    return Total_index
"""

#call the timeit() method 4 times
   
print(timeit.timeit(stmt=code))

arr = []
for _ in range(100):
    arr.append(random.randint(1, 100))
    
def search_matched_sum(arr : list, target : int) -> list:
    arr = mergeSort(arr)
    min_index = ()
    max_index = ()
    value_index = ()
    Total_index = []
    i = 0
    while i < len(arr):
        temp = target - arr[i]
        if temp in arr[arr.index(arr[i]):]:
            min_index = arr[i]
            max_index = temp
            value_index = (min_index, max_index)
            if value_index not in Total_index:
                Total_index.append(value_index)
            i += 1
        
        else:
            i += 1
    return Total_index

# %timeit search_matched_sum(arr, 6)
# Out:
# 0.18300109999995584
# 373 µs ± 15.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# # CASE 3
#
# ### 정렬하지 않는 경우
#
# ```python
# def search_matched_sum(arr : list, target : int) -> list:
#     min_index = ()
#     max_index = ()
#     target_index = ()
#     Total_index = []
#     for i in range(len(arr)):
#         temp = target - arr[i]
#         if temp in arr:
#             min_index = arr.index(arr[i])
#             max_index = arr.index(temp)
#             if min_index > max_index:
#                 t = min_index
#                 min_index = max_index
#                 max_index = t
#             target_index = (min_index, max_index)
#             if target_index not in Total_index:
#                 Total_index.append(target_index)
#             continue
#         else:
#             continue
#
#     return Total_index
# ```
# arr을 정렬하지 않은 채로 index를 찾아준 후 <span style='color: lightskyblue'>min_index</span>와 <span style='color: purple'>max_index</span>를 비교하여 큰 수를 <span style='color: purple'>max_index</span>로 넣어줌으로써 같은 값들의 중복을 제거하여 주었다.

# %%
import timeit
code="""
def search_matched_sum(arr : list, target : int) -> list:
    min_index = ()
    max_index = ()
    target_index = ()
    Total_index = []
    for i in range(len(arr)):
        temp = target - arr[i]
        if temp in arr:
            min_index = arr.index(arr[i])
            max_index = arr.index(temp)
            if min_index > max_index:
                t = min_index
                min_index = max_index
                max_index = t
            target_index = (min_index, max_index)
            if target_index not in Total_index:
                Total_index.append(target_index)
            continue
        else:
            continue

    return Total_index
"""

#call the timeit() method 4 times
print(timeit.timeit(stmt=code))

arr = []
for _ in range(100):
    arr.append(random.randint(1, 100))

def search_matched_sum(arr : list, target : int) -> list:
    min_index = ()
    max_index = ()
    target_index = ()
    Total_index = []
    for i in range(len(arr)):
        temp = target - arr[i]
        if temp in arr:
            min_index = arr.index(arr[i])
            max_index = arr.index(temp)
            if min_index > max_index:
                t = min_index
                min_index = max_index
                max_index = t
            target_index = (min_index, max_index)
            if target_index not in Total_index:
                Total_index.append(target_index)
            continue
        else:
            continue

    return Total_index

# %timeit search_matched_sum(arr, 6)
# Out:
# 0.15373840000029304
# 108 µs ± 3.17 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# # Result
#
# 처음에는 arr을 지정하여 작은 수로만 실행시켜 실행 시간이 차이가 별로 나지 않는다고 생각하였고, arr을 random 모듈을 <span style='color:green'>import</span>하여 1부터 100사이의 수로 이루어진 값이 100개로 이루어진 리스트로 만들어주어 입력하여 주었다. 하지만 $nolgn$ 과 $n^2$의 시간 차이는 전보다 줄어들었고 test_fun의 결과부터 이해가 가지않았다.
# 하지만 항상 $n^2$의 *TimeComplexity*를 가지는 bubbleSort와 항상 $nlogn$의 *TimeComplexity*를 가지는 mergeSort를 비교하였을 때, 평균 속도는 mergeSort가 확실히 빠르다는 결과가 나타났다.
